# %% [markdown]
# # PS4 - Problem 6 - Reinforcement Learning: The inverted pendulum

# %% [markdown]
# Implemented in the dedicated `p06_cartpole.py`. Please, notice that in order to allow running the script both by terminal and within the notebook while specifying a different seed, the code was updated to allow the `main` function to receive a `seed` parameter.
#
# The following cell plots the results for the seeds in the range $[0,3]$.
#
# With respect to the third question in the problem description, we observe that, independently from the starting seed, the value function smoothes out after some iterations, attaining the same average value. This implies that the algorithm is stable as it allows to reach the same result from multiple different initializations.

# %%
import sys
sys.path.append('src')
from src.p06_cartpole import main

# %%
main(0)

# %%
main(1)

# %%
main(2)

# %%
main(3)
