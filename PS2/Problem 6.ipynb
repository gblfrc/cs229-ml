# %% [markdown]
# # PS2 - Problem 6 - Spam classification

# %% [markdown]
# ### (a) - (d)
# All points for this problem have been implemented in the dedicated `src/p06_spam.py`. Run that file to verify its behavior and check the results.
